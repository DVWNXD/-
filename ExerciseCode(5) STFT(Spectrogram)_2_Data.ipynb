# %%
# %matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# ## 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import math

# %% [markdown]
# ## 데이터 불러오기

# %%
Data = pd.read_csv('./ExampleData', sep=',', header=None)
Data.shape
# Out:
# (2774, 4)

# %% [markdown]
# ## Time domain 그래프

# %%
plt.plot(Data.iloc[:,0], Data.iloc[:,1])
plt.grid()
    # Data.iloc[:,0] : 시간열 // Data.iloc[:,1] : 신호열 (반경방향 가속도)
    # 데이터에 따라 맞추어 변경
plt.xlabel('time(s)')
plt.ylabel('acceleration(g)')
plt.title('Radial Acceleration')
#plt.xlim(0,0.2167)
plt.show()

# %% [markdown]
# ## STFT 실행 (Spectrogram 생성)

# %%
Fs = 12800
x  = Data.iloc[:,1].values # 데이터의 신호열 선택(가속도 데이터)

# %%
f,t,Sxx = signal.spectrogram(x, Fs, nperseg = 78)
f.shape, t.shape, Sxx.shape
# Out:
# ((40,), (40,), (40, 40))

# %% [markdown]
# ## STFT 그래프 (Frequency & Time domain)

# %%
plt.figure(figsize=(9,6))
plt.pcolormesh(t, f, Sxx, vmax = 0.01, cmap = 'hot', alpha = 0.7) #VMAX값 차이두면 그래프 보기 편해짐
# plt.ylim((0, 6400))
# plt.xlim((0,0.144))
plt.xlabel('Time(s)', fontsize=12)
plt.ylabel('Frequency(Hz)', fontsize=12)
plt.title('ExampleData STFT Result', fontsize=20)
plt.colorbar()
plt.show()
# Out:
# <ipython-input-11-59c24522a505>:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(t, f, Sxx, vmax = 0.01, cmap = 'hot', alpha = 0.7)
