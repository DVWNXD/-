# %%
# %matplotlib                    # Pyplot 그래프 새창에서 열기 옵션

# %%
# %matplotlib inline             # Pyplot 그래프 새창에서 열기 '취소' 옵션

# %%
pd.set_option('display.max_rows',    100)      # DataFrame 데이터 확인 시 최대 표시 행 수
pd.set_option('display.max_columns', 100)      # DataFrame 데이터 확인 시 최대 표시 열 수

# %% [markdown]
# ## 라이브러리 import

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import pickle
from sklearn.neighbors import KNeighborsClassifier
import joblib
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## 데이터 불러오기

# %%
Fold = 5

# k-fold 학습/검증 데이터
for i in range(Fold):
    
    path1 = './K_FoldData/Training_Fold%d'%(i+1)
    path2 = './K_FoldData/Validation_Fold%d'%(i+1)
    c1 = 'Training_Fold%d   = np.array(pd.read_csv(path1, sep=",", header=None))'%(i+1)
    c2 = 'Validation_Fold%d = np.array(pd.read_csv(path2, sep=",", header=None))'%(i+1)
    exec(c1)
    exec(c2)

# K-fold 학습/검증 레이블
TrainingFold_Label   = np.array(pd.read_csv('./K_FoldData/TrainingFold_Label'  , sep=",", header=None).T.squeeze())
ValidationFold_Label = np.array(pd.read_csv('./K_FoldData/ValidationFold_Label', sep=",", header=None).T.squeeze())
    
    
# 전체 학습용 데이터
Training_All       = np.array(pd.read_csv('./K_FoldData/Training_All', sep = ",", header = None))
Training_All_Label = np.array(pd.read_csv('./K_FoldData/Training_All_Label', sep = ",", header = None).T.squeeze())


# 평가 데이터
Test_Data  = np.array(pd.read_csv('./K_FoldData/Test_Data' , sep=",", header=None))
Test_Label = np.array(pd.read_csv('./K_FoldData/Test_Label', sep=",", header=None))

# %% [markdown]
# ## Grid Search 기반 Hyperparameter 별 성능 확인

# %% [markdown]
# #### 1. 반복문 활용

# %%
Fold = 5

# 비교할 하이퍼파라미터들 리스트 형태로 만들기
param_weight      = ['uniform', 'distance']                 # 데이터 간 거리에 따른 가중치 유무
param_n_neighbors = list(range(3, 20, 4))                   # 계산할 주변(이웃) 데이터 개수
param_metric      = ['euclidean', 'manhattan', 'minkowski'] # 거리 계산 방법

# 파라미터별 정확도 기록할 변수 설정
Accuracy_df = pd.DataFrame(np.zeros(shape=(len(param_n_neighbors)*len(param_weight)*len(param_metric),4)), #2*5*3
                           columns=['weight', 'n_neighbors', 'metric', 'Accuracy'])
cnt = 0 #폴드 들어갈때 카운트

# Grid Search 코드
for Weight in param_weight: #리스트에 있는 원소 하나하나다 넣어주면서 감

    for Nnb in param_n_neighbors: #변수들이 할당해서 for문 안에서 돌아간다

        for Metric in param_metric:
            
            ValidScore = 0 # 모델 바뀔 때마다 검증정확도 변수 초기화
            
            for i in range(Fold):
                c1 = 'Training_CurrentFold = Training_Fold%d'%(i+1)
                exec(c1)
                c2 = 'Validation_CurrentFold = Validation_Fold%d'%(i+1)
                exec(c2)
                
                tempsvmModel   = KNeighborsClassifier(n_neighbors=Nnb,
                                                      weights=Weight,
                                                      metric=Metric).fit(Training_CurrentFold, TrainingFold_Label) # 학습
                tempValidScore = tempsvmModel.score(Validation_CurrentFold, ValidationFold_Label)                  # 검증
                
                ValidScore += tempValidScore # Fold 별 검증 정확도 합산 
                
            Acc = ValidScore/Fold # 평균 검증 정확도
            Accuracy_df.iloc[cnt, :] = [Weight, Nnb, Metric, Acc] # 모델의 하이퍼파라미터, 검증정확도 대입
            cnt += 1

# %%
Accuracy_df
# Out:
#       weight  n_neighbors     metric  Accuracy
# 0    uniform          3.0  euclidean  0.993750
# 1    uniform          3.0  manhattan  0.993750
# 2    uniform          3.0  minkowski  0.993750
# 3    uniform          7.0  euclidean  0.987500
# 4    uniform          7.0  manhattan  0.993750
# 5    uniform          7.0  minkowski  0.987500
# 6    uniform         11.0  euclidean  0.984375
# 7    uniform         11.0  manhattan  0.993750
# 8    uniform         11.0  minkowski  0.984375
# 9    uniform         15.0  euclidean  0.984375
# 10   uniform         15.0  manhattan  0.993750
# 11   uniform         15.0  minkowski  0.984375
# 12   uniform         19.0  euclidean  0.984375
# 13   uniform         19.0  manhattan  0.990625
# 14   uniform         19.0  minkowski  0.984375
# 15  distance          3.0  euclidean  0.993750
# 16  distance          3.0  manhattan  0.993750
# 17  distance          3.0  minkowski  0.993750
# 18  distance          7.0  euclidean  0.987500
# 19  distance          7.0  manhattan  0.993750
# 20  distance          7.0  minkowski  0.987500
# 21  distance         11.0  euclidean  0.987500
# 22  distance         11.0  manhattan  0.993750
# 23  distance         11.0  minkowski  0.987500
# 24  distance         15.0  euclidean  0.987500
# 25  distance         15.0  manhattan  0.993750
# 26  distance         15.0  minkowski  0.987500
# 27  distance         19.0  euclidean  0.987500
# 28  distance         19.0  manhattan  0.993750
# 29  distance         19.0  minkowski  0.987500

# %%
Accuracy_df_sorted = Accuracy_df.sort_values(by = ['Accuracy'], ascending = False) # 성능 확인
Accuracy_df_sorted
# Out:
#       weight  n_neighbors     metric  Accuracy
# 0    uniform          3.0  euclidean  0.993750
# 10   uniform         15.0  manhattan  0.993750
# 28  distance         19.0  manhattan  0.993750
# 25  distance         15.0  manhattan  0.993750
# 22  distance         11.0  manhattan  0.993750
# 19  distance          7.0  manhattan  0.993750
# 17  distance          3.0  minkowski  0.993750
# 16  distance          3.0  manhattan  0.993750
# 1    uniform          3.0  manhattan  0.993750
# 15  distance          3.0  euclidean  0.993750
# 2    uniform          3.0  minkowski  0.993750
# 7    uniform         11.0  manhattan  0.993750
# 4    uniform          7.0  manhattan  0.993750
# 13   uniform         19.0  manhattan  0.990625
# 20  distance          7.0  minkowski  0.987500
# 21  distance         11.0  euclidean  0.987500
# 27  distance         19.0  euclidean  0.987500
# 26  distance         15.0  minkowski  0.987500
# 3    uniform          7.0  euclidean  0.987500
# 24  distance         15.0  euclidean  0.987500
# 23  distance         11.0  minkowski  0.987500
# 29  distance         19.0  minkowski  0.987500
# 5    uniform          7.0  minkowski  0.987500
# 18  distance          7.0  euclidean  0.987500
# 11   uniform         15.0  minkowski  0.984375
# 6    uniform         11.0  euclidean  0.984375
# 8    uniform         11.0  minkowski  0.984375
# 14   uniform         19.0  minkowski  0.984375
# 12   uniform         19.0  euclidean  0.984375
# 9    uniform         15.0  euclidean  0.984375

# %% [markdown]
# #### 2. sklearn.model_selection.GridSearchCV 함수 활용 (K-fold Cross Validation 내장)

# %%
# 비교할 하이퍼파라미터 사전(Dictionary) 형태로 만들기 gridcvv때문에 특정 키가 있고 거기에 들어간다
GridParams = {
    'weights' : ['uniform', 'distance'],
    'n_neighbors' : list(range(3, 20, 4)),
    'metric' : ['euclidean', 'manhattan', 'minkowski']
}

# %%
tempknnModel = KNeighborsClassifier() #위의 인자는 고정
GS_model = GridSearchCV(tempknnModel, GridParams, cv = 5)

GS_model.fit(Training_All, Training_All_Label) #test 데이터 제외 . tab키 사용하면 함수 사용가능한거 나옴
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 7, 11, 15, 19],
#                          'weights': ['uniform', 'distance']})

# %%
print('Total Combination of Hyperparameters :', len(GS_model.cv_results_.get('params')))
# Out:
# Total Combination of Hyperparameters : 30

# %%
pd.DataFrame(GS_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.001643      0.000549         0.009930        0.003402    euclidean
# 1        0.000743      0.000415         0.002571        0.000474    euclidean
# 2        0.001122      0.000369         0.006546        0.000826    euclidean
# 3        0.001042      0.000196         0.002038        0.000068    euclidean
# 4        0.001015      0.000183         0.005805        0.000200    euclidean
# 5        0.000995      0.000021         0.002603        0.000478    euclidean
# 6        0.000997      0.000028         0.006416        0.000785    euclidean
# 7        0.000991      0.000013         0.002248        0.000485    euclidean
# 8        0.001016      0.000055         0.006986        0.000663    euclidean
# 9        0.001369      0.000454         0.003245        0.000769    euclidean
# 10       0.001100      0.000491         0.006424        0.000489    manhattan
# 11       0.001008      0.000021         0.002868        0.000460    manhattan
# 12       0.001139      0.000282         0.005593        0.000889    manhattan
# 13       0.000629      0.000404         0.001120        0.000309    manhattan
# 14       0.000575      0.000471         0.003485        0.000381    manhattan
# 15       0.000400      0.000489         0.001606        0.000477    manhattan
# 16       0.000598      0.000488         0.004016        0.000042    manhattan
# 17       0.000697      0.000427         0.001920        0.000122    manhattan
# 18       0.000758      0.000383         0.004184        0.000748    manhattan
# 19       0.000823      0.000777         0.002579        0.000500    manhattan
# 20       0.000998      0.000632         0.005385        0.001849    minkowski
# 21       0.000518      0.000448         0.001440        0.000456    minkowski
# 22       0.000782      0.000392         0.003207        0.000392    minkowski
# 23       0.001009      0.000021         0.001049        0.000135    minkowski
# 24       0.000200      0.000399         0.003539        0.000430    minkowski
# 25       0.000310      0.000405         0.001397        0.000490    minkowski
# 26       0.000898      0.000513         0.005085        0.000903    minkowski
# 27       0.001003      0.000207         0.002195        0.000919    minkowski
# 28       0.001062      0.000648         0.003931        0.000558    minkowski
# 29       0.001123      0.000482         0.001759        0.000706    minkowski
#
#    param_n_neighbors param_weights  \
# 0                  3       uniform
# 1                  3      distance
# 2                  7       uniform
# 3                  7      distance
# 4                 11       uniform
# 5                 11      distance
# 6                 15       uniform
# 7                 15      distance
# 8                 19       uniform
# 9                 19      distance
# 10                 3       uniform
# 11                 3      distance
# 12                 7       uniform
# 13                 7      distance
# 14                11       uniform
# 15                11      distance
# 16                15       uniform
# 17                15      distance
# 18                19       uniform
# 19                19      distance
# 20                 3       uniform
# 21                 3      distance
# 22                 7       uniform
# 23                 7      distance
# 24                11       uniform
# 25                11      distance
# 26                15       uniform
# 27                15      distance
# 28                19       uniform
# 29                19      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.968750
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.968750
# 2   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.937500
# 3   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.937500
# 4   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.937500
# 5   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.937500
# 6   {'metric': 'euclidean', 'n_neighbors': 15, 'we...           0.937500
# 7   {'metric': 'euclidean', 'n_neighbors': 15, 'we...           0.937500
# 8   {'metric': 'euclidean', 'n_neighbors': 19, 'we...           0.937500
# 9   {'metric': 'euclidean', 'n_neighbors': 19, 'we...           0.937500
# 10  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.968750
# 11  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.968750
# 12  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.968750
# 13  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.968750
# 14  {'metric': 'manhattan', 'n_neighbors': 11, 'we...           0.968750
# 15  {'metric': 'manhattan', 'n_neighbors': 11, 'we...           0.968750
# 16  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           0.968750
# 17  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           0.968750
# 18  {'metric': 'manhattan', 'n_neighbors': 19, 'we...           0.953125
# 19  {'metric': 'manhattan', 'n_neighbors': 19, 'we...           0.968750
# 20  {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.968750
# 21  {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.968750
# 22  {'metric': 'minkowski', 'n_neighbors': 7, 'wei...           0.937500
# 23  {'metric': 'minkowski', 'n_neighbors': 7, 'wei...           0.937500
# 24  {'metric': 'minkowski', 'n_neighbors': 11, 'we...           0.937500
# 25  {'metric': 'minkowski', 'n_neighbors': 11, 'we...           0.937500
# 26  {'metric': 'minkowski', 'n_neighbors': 15, 'we...           0.937500
# 27  {'metric': 'minkowski', 'n_neighbors': 15, 'we...           0.937500
# 28  {'metric': 'minkowski', 'n_neighbors': 19, 'we...           0.937500
# 29  {'metric': 'minkowski', 'n_neighbors': 19, 'we...           0.937500
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000                1.0                1.0
# 1            1.000000                1.0                1.0
# 2            1.000000                1.0                1.0
# 3            1.000000                1.0                1.0
# 4            0.984375                1.0                1.0
# 5            1.000000                1.0                1.0
# 6            0.984375                1.0                1.0
# 7            1.000000                1.0                1.0
# 8            0.984375                1.0                1.0
# 9            1.000000                1.0                1.0
# 10           1.000000                1.0                1.0
# 11           1.000000                1.0                1.0
# 12           1.000000                1.0                1.0
# 13           1.000000                1.0                1.0
# 14           1.000000                1.0                1.0
# 15           1.000000                1.0                1.0
# 16           1.000000                1.0                1.0
# 17           1.000000                1.0                1.0
# 18           1.000000                1.0                1.0
# 19           1.000000                1.0                1.0
# 20           1.000000                1.0                1.0
# 21           1.000000                1.0                1.0
# 22           1.000000                1.0                1.0
# 23           1.000000                1.0                1.0
# 24           0.984375                1.0                1.0
# 25           1.000000                1.0                1.0
# 26           0.984375                1.0                1.0
# 27           1.000000                1.0                1.0
# 28           0.984375                1.0                1.0
# 29           1.000000                1.0                1.0
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.993750        0.012500                1
# 1                 1.0         0.993750        0.012500                1
# 2                 1.0         0.987500        0.025000               15
# 3                 1.0         0.987500        0.025000               15
# 4                 1.0         0.984375        0.024206               25
# 5                 1.0         0.987500        0.025000               15
# 6                 1.0         0.984375        0.024206               25
# 7                 1.0         0.987500        0.025000               15
# 8                 1.0         0.984375        0.024206               25
# 9                 1.0         0.987500        0.025000               15
# 10                1.0         0.993750        0.012500                1
# 11                1.0         0.993750        0.012500                1
# 12                1.0         0.993750        0.012500                1
# 13                1.0         0.993750        0.012500                1
# 14                1.0         0.993750        0.012500                1
# 15                1.0         0.993750        0.012500                1
# 16                1.0         0.993750        0.012500                1
# 17                1.0         0.993750        0.012500                1
# 18                1.0         0.990625        0.018750               14
# 19                1.0         0.993750        0.012500                1
# 20                1.0         0.993750        0.012500                1
# 21                1.0         0.993750        0.012500                1
# 22                1.0         0.987500        0.025000               15
# 23                1.0         0.987500        0.025000               15
# 24                1.0         0.984375        0.024206               25
# 25                1.0         0.987500        0.025000               15
# 26                1.0         0.984375        0.024206               25
# 27                1.0         0.987500        0.025000               15
# 28                1.0         0.984375        0.024206               25
# 29                1.0         0.987500        0.025000               15

# %%
print('Best Parameters : ', GS_model.best_params_)
print('Best Score : {}%'.format(round(GS_model.best_score_*100, 2)) )

# 모델 평가
# Test_Score = GS_model.score(Test_Data, Test_Label)
# print('Best Test Score : {}%'.format(round(Test_Score*100, 2)) )
# Out:
# Best Parameters :  {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Score : 99.38%
